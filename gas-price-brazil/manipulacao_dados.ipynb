# %%
import pandas as pd

# %%
data = pd.read_csv('GasPricesinBrazil_2004-2019.csv', sep=';')
display(data)
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
data = data.drop('Unnamed: 0', axis=1)
display(data)
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# Todo dataset (dados estruturados) é um Data Frame

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(f'O Data Frame possui {data.shape[0]} linhas e {data.shape[1]} colunas.')
# Out:
# O Data Frame possui 106823 linhas e 20 colunas.

# %%
display(data[['DATA INICIAL', 'DATA FINAL','REGIÃO', 'PRODUTO', 'PREÇO MÉDIO REVENDA']])
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO           PRODUTO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 1        2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 2        2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  ETANOL HIDRATADO
# 4        2004-05-09  2004-05-15      NORDESTE  ETANOL HIDRATADO
# ...             ...         ...           ...               ...
# 106818   2019-06-23  2019-06-29      NORDESTE               GNV
# 106819   2019-06-23  2019-06-29           SUL               GNV
# 106820   2019-06-23  2019-06-29           SUL               GNV
# 106821   2019-06-23  2019-06-29       SUDESTE               GNV
# 106822   2019-06-23  2019-06-29      NORDESTE               GNV
#
#         PREÇO MÉDIO REVENDA
# 0                     1.288
# 1                     1.162
# 2                     1.389
# 3                     1.262
# 4                     1.181
# ...

# %%
nordeste_df = data.loc[data['REGIÃO'] == 'NORDESTE']
display(nordeste_df[['DATA INICIAL', 'DATA FINAL','REGIÃO', 'PRODUTO', 'PREÇO MÉDIO REVENDA']])
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO           PRODUTO  \
# 4        2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO
# 5        2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO
# 6        2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO
# 7        2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO
# 8        2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO
# ...             ...         ...       ...               ...
# 106810   2019-06-23  2019-06-29  NORDESTE               GNV
# 106814   2019-06-23  2019-06-29  NORDESTE               GNV
# 106816   2019-06-23  2019-06-29  NORDESTE               GNV
# 106818   2019-06-23  2019-06-29  NORDESTE               GNV
# 106822   2019-06-23  2019-06-29  NORDESTE               GNV
#
#         PREÇO MÉDIO REVENDA
# 4                     1.181
# 5                     1.383
# 6                     1.453
# 7                     1.631
# 8                     1.284
# ...                     ...
# 106810                3.656
# ...

# %%
nordeste_gasolina_df = nordeste_df.loc[data['PRODUTO'] == 'GASOLINA COMUM']
nordeste_etanol_df = nordeste_df.loc[data['PRODUTO'] == 'ETANOL HIDRATADO']
nordeste_gnv_df = nordeste_df.loc[data['PRODUTO'] == 'GNV']
nordeste_glp_df = nordeste_df.loc[data['PRODUTO'] == 'GLP']
nordeste_diesel_df = nordeste_df.loc[data['PRODUTO'] == 'ÓLEO DIESEL']
nordeste_diesels10_df = nordeste_df.loc[data['PRODUTO'] == 'ÓLEO DIESEL S10']

display(nordeste_gasolina_df[['DATA INICIAL', 'DATA FINAL','REGIÃO', 'PRODUTO', 'PREÇO MÉDIO REVENDA']].head())
# Out:
#       DATA INICIAL  DATA FINAL    REGIÃO         PRODUTO  PREÇO MÉDIO REVENDA
# 12068   2004-05-09  2004-05-15  NORDESTE  GASOLINA COMUM                2.090
# 12069   2004-05-09  2004-05-15  NORDESTE  GASOLINA COMUM                2.040
# 12070   2004-05-09  2004-05-15  NORDESTE  GASOLINA COMUM                2.148
# 12071   2004-05-09  2004-05-15  NORDESTE  GASOLINA COMUM                2.089
# 12072   2004-05-09  2004-05-15  NORDESTE  GASOLINA COMUM                1.989

# %%
display(nordeste_etanol_df[['DATA INICIAL', 'DATA FINAL','REGIÃO', 'PRODUTO', 'PREÇO MÉDIO REVENDA']].head())
# Out:
#   DATA INICIAL  DATA FINAL    REGIÃO           PRODUTO  PREÇO MÉDIO REVENDA
# 4   2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO                1.181
# 5   2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO                1.383
# 6   2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO                1.453
# 7   2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO                1.631
# 8   2004-05-09  2004-05-15  NORDESTE  ETANOL HIDRATADO                1.284

# %%
display(nordeste_gnv_df[['DATA INICIAL', 'DATA FINAL','REGIÃO', 'PRODUTO', 'PREÇO MÉDIO REVENDA']].head())
# Out:
#       DATA INICIAL  DATA FINAL    REGIÃO PRODUTO  PREÇO MÉDIO REVENDA
# 36197   2004-05-09  2004-05-15  NORDESTE     GNV                1.084
# 36198   2004-05-09  2004-05-15  NORDESTE     GNV                1.079
# 36199   2004-05-09  2004-05-15  NORDESTE     GNV                1.184
# 36200   2004-05-09  2004-05-15  NORDESTE     GNV                1.149
# 36201   2004-05-09  2004-05-15  NORDESTE     GNV                1.147

# %%
display(nordeste_diesel_df[['DATA INICIAL', 'DATA FINAL','REGIÃO', 'PRODUTO', 'PREÇO MÉDIO REVENDA']].head())
# Out:
#       DATA INICIAL  DATA FINAL    REGIÃO      PRODUTO  PREÇO MÉDIO REVENDA
# 43551   2004-05-09  2004-05-15  NORDESTE  ÓLEO DIESEL                1.362
# 43552   2004-05-09  2004-05-15  NORDESTE  ÓLEO DIESEL                1.335
# 43553   2004-05-09  2004-05-15  NORDESTE  ÓLEO DIESEL                1.548
# 43554   2004-05-09  2004-05-15  NORDESTE  ÓLEO DIESEL                1.363
# 43555   2004-05-09  2004-05-15  NORDESTE  ÓLEO DIESEL                1.314

# %%
regiao = data[['REGIÃO', 'PRODUTO']].groupby('REGIÃO').sum()

display(regiao)
# Out:
#                                                         PRODUTO
# REGIÃO
# CENTRO OESTE  ETANOL HIDRATADOETANOL HIDRATADOETANOL HIDRATA...
# NORDESTE      ETANOL HIDRATADOETANOL HIDRATADOETANOL HIDRATA...
# NORTE         ETANOL HIDRATADOETANOL HIDRATADOETANOL HIDRATA...
# SUDESTE       ETANOL HIDRATADOETANOL HIDRATADOETANOL HIDRATA...
# SUL           ETANOL HIDRATADOETANOL HIDRATADOETANOL HIDRATA...

# %%
data.loc[4392]
# Out:
# DATA INICIAL                           2007-07-01
# DATA FINAL                             2007-07-07
# REGIÃO                                    SUDESTE
# ESTADO                                  SAO PAULO
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                 3543
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.214
# DESVIO PADRÃO REVENDA                       0.117
# PREÇO MÍNIMO REVENDA                         0.85
# PREÇO MÁXIMO REVENDA                        1.699
# MARGEM MÉDIA REVENDA                        0.335
# COEF DE VARIAÇÃO REVENDA                    0.096
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.879
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.089
# PREÇO MÍNIMO DISTRIBUIÇÃO                   0.685
# PREÇO MÁXIMO DISTRIBUIÇÃO                  1.2649
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.101
# MÊS                                             7
# ...

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# Selecionar apenas os preços de São Paulo

# %%
selecao = data['ESTADO'] == 'SAO PAULO'

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True)
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...
